# %% [markdown]
# ## Setup

# %%
# set environment variable
import os
os.environ["OMP_NUM_THREADS"] = "1"

# %%
# imports and dependenceis
import pandas as pd
import hvplot.pandas
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='f569ffa5-bc21-406e-9b24-0755475773a9'>
#   <div id="ffdcdae8-c9c0-44d3-85f3-c878fec84a5f" data-root-id="f569ffa5-bc21-406e-9b24-0755475773a9" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# load data into df
crypto_df = pd.read_csv('Resources/crypto_market_data.csv', index_col='coin_id')
crypto_df.head(10)
# Out:
#                  price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                              1.08388                     7.60278
# ethereum                             0.22392                    10.38134
# tether                              -0.21173                     0.04935
# ripple                              -0.37819                    -0.60926
# bitcoin-cash                         2.90585                    17.09717
# binancecoin                          2.10423                    12.85511
# chainlink                           -0.23935                    20.69459
# cardano                              0.00322                    13.99302
# litecoin                            -0.06341                     6.60221
# bitcoin-cash-sv                      0.92530                     3.29641
#
#                  price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# ...

# %% [markdown]
# ## Data Check

# %%
# check data types
crypto_df.dtypes
# Out:
# price_change_percentage_24h     float64
# price_change_percentage_7d      float64
# price_change_percentage_14d     float64
# price_change_percentage_30d     float64
# price_change_percentage_60d     float64
# price_change_percentage_200d    float64
# price_change_percentage_1y      float64
# dtype: object

# %%
# get summary stats
crypto_df.describe()
# Out:
#        price_change_percentage_24h  price_change_percentage_7d  \
# count                    41.000000                   41.000000
# mean                     -0.269686                    4.497147
# std                       2.694793                    6.375218
# min                     -13.527860                   -6.094560
# 25%                      -0.608970                    0.047260
# 50%                      -0.063410                    3.296410
# 75%                       0.612090                    7.602780
# max                       4.840330                   20.694590
#
#        price_change_percentage_14d  price_change_percentage_30d  \
# count                    41.000000                    41.000000
# mean                      0.185787                     1.545693
# std                       8.376939                    26.344218
# min                     -18.158900                   -34.705480
# 25%                      -5.026620                   -10.438470
# ...

# %%
# plot data
crypto_df.hvplot.line(
    width=800,
    height=400,
    rot=90
)
# Out:
# :NdOverlay   [Variable]
#    :Curve   [coin_id]   (value)

# %% [markdown]
# ## Scale Data
# ---

# %%
# save column names
col_names = list(crypto_df.columns)

# normalize data
scaled_cols = StandardScaler().fit_transform(crypto_df[col_names])

# create new df
scaled_df = pd.DataFrame(
    scaled_cols,
    columns=col_names,
    index=crypto_df.index
)

# display
scaled_df.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# ...

# %% [markdown]
# ## Functions: K Means
# ---

# %% [markdown]
# ### Get elbow plot

# %%
# function for elbow plot
def get_elbow_plot(main_df):
    # get copy of df
    df = main_df.copy()

    # get inertias for k vals
    inertias = []
    k_vals = list(range(1, 11))

    for k in k_vals:
        # fit k means model
        k_model = KMeans(n_clusters=k, random_state=0)
        k_model.fit(df)

        # save inertia
        inertias.append(k_model.inertia_)

    # save to df
    elbow_df = pd.DataFrame({
        'k': k_vals, 
        'inertia': inertias
    })

    # plot
    elbow_plot = elbow_df.hvplot.line(
        x='k',
        y='inertia',
        xticks=k
    )
    
    # return 
    return elbow_plot

# %% [markdown]
# ### Perform k means with best k value

# %%
# define function to get best k value with CH score and perform k means
def get_k_means_predictions(main_df, k_list, x_val='x', y_val='y'):
    # get copy of df
    df = main_df.copy()

    # -----------------
    # find best k value
    # -----------------
    # score the two k values
    k_scores = []

    for k in k_list:

        # get scores
        k_model = KMeans(n_clusters=k, random_state=0)
        k_model.fit(df)
        labels = k_model.labels_
        score = metrics.calinski_harabasz_score(df, labels)
        k_scores.append({
            'k': k,
            'score': score
        })
        
    # display scores
    print(k_scores)

    # get best k value
    k_val = max(k_scores, key=lambda x: x['score'])['k']
    print(f'Best k value: {k_val}')

    # -------------------
    # perform k means
    # -------------------
    # build k means model with best k value
    k_model = KMeans(n_clusters=k_val, random_state=0)
    k_model.fit(df)

    # predict model clusters
    predictions = k_model.predict(df)

    # add predictions to df
    predictions_df = df.copy()
    predictions_df['predictions'] = predictions

    # -------------------
    # get scatter plot
    # -------------------
    scatter_plot = predictions_df.hvplot.scatter(
        x=x_val,
        y=y_val,
        by='predictions',
        hover_cols='coin_id'
    )

    # return df
    return predictions_df, scatter_plot

# %% [markdown]
# ## K Means with Full Scaled Data
# ---

# %% [markdown]
# ### Elbow method (between k=4 and k=5)

# %%
# perform elbow method --> between k=4 and k=5
scaled_elbow_plot = get_elbow_plot(scaled_df)
scaled_elbow_plot
# Out:
# :Curve   [k]   (inertia)

# %% [markdown]
# ### Get best k val with CH score and cluster--> k=4

# %%
# set up for function
k_options = [4, 5]  #between k=4 and k=5
x_val = 'price_change_percentage_24h'
y_val = 'price_change_percentage_7d'

# peform function
scaled_predictions_df, scaled_predictions_plot = get_k_means_predictions(scaled_df, k_options, x_val=x_val, y_val=y_val)

# display df and plot
scaled_predictions_df.head()
# Out:
# [{'k': 4, 'score': 32.45985294262567}, {'k': 5, 'score': 30.007650175819986}]
# Best k value: 4
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
# ...

# %%
# display plot
scaled_predictions_plot
# Out:
# :NdOverlay   [predictions]
#    :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d,coin_id)

# %% [markdown]
# ## K Means with PCA
# ---

# %% [markdown]
# ### See PCA explained variance (going with 3 principal components)

# %%
# fit pca model on scaled df
pca = PCA()
crypto_pca = pca.fit_transform(scaled_df)

# calcualte explained variance ratio
pca.explained_variance_ratio_
# Out:
# array([0.3719856 , 0.34700813, 0.17603793, 0.05705673, 0.02729754,
#        0.0164632 , 0.00415086])

# %% [markdown]
# ### Perform PCA

# %%
# fit pca model on scaled df
pca = PCA(n_components=3)
crypto_pca = pca.fit_transform(scaled_df)

# create pca df
crypto_pca_df = pd.DataFrame(
    crypto_pca,
    columns=['PC1', 'PC2', 'PC3'],
    index=scaled_df.index
)

# review df
crypto_pca_df.head()
# Out:
#                    PC1       PC2       PC3
# coin_id
# bitcoin      -0.600667  0.842760  0.461595
# ethereum     -0.458261  0.458466  0.952877
# tether       -0.433070 -0.168126 -0.641752
# ripple       -0.471835 -0.222660 -0.479053
# bitcoin-cash -1.157800  2.041209  1.859715

# %% [markdown]
# ### Elbow method

# %%
# perform elbow method --> between k=4 and k=5
pca_elbow_plot = get_elbow_plot(crypto_pca_df)
pca_elbow_plot
# Out:
# :Curve   [k]   (inertia)

# %% [markdown]
# ### Get best k val with CH score and cluster--> k=4 (same as before)

# %%
# set up for function
k_options = [4, 5]  #between k=4 and k=5
x_val = 'PC1'
y_val = 'PC2'

# peform function
pca_predictions_df, pca_predictions_plot = get_k_means_predictions(crypto_pca_df, k_options, x_val=x_val, y_val=y_val)

# display df and plot
pca_predictions_df.head()
# Out:
# [{'k': 4, 'score': 51.45569397098449}, {'k': 5, 'score': 46.8998290149141}]
# Best k value: 4
#                    PC1       PC2       PC3  predictions
# coin_id
# bitcoin      -0.600667  0.842760  0.461595            2
# ethereum     -0.458261  0.458466  0.952877            2
# tether       -0.433070 -0.168126 -0.641752            0
# ripple       -0.471835 -0.222660 -0.479053            0
# bitcoin-cash -1.157800  2.041209  1.859715            2

# %%
# display plot
pca_predictions_plot
# Out:
# :NdOverlay   [predictions]
#    :Scatter   [PC1]   (PC2,coin_id)

# %% [markdown]
# ## Compare
# ---

# %% [markdown]
# ### Elbow method plots--> PCA better (lower inertia at best k val of 4)

# %%
# create composite plot
scaled_elbow_plot + pca_elbow_plot
# Out:
# :Layout
#    .Curve.I  :Curve   [k]   (inertia)
#    .Curve.II :Curve   [k]   (inertia)

# %% [markdown]
# ### Cluster plots

# %%
# create composite plot
scaled_predictions_plot + pca_predictions_plot
# Out:
# :Layout
#    .NdOverlay.I  :NdOverlay   [predictions]
#       :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d,coin_id)
#    .NdOverlay.II :NdOverlay   [predictions]
#       :Scatter   [PC1]   (PC2,coin_id)

# %% [markdown]
# ## CH Scores--> PCA is better (significantly higher score)

# %%
# get scores for both (scaled then crypto)
scores = []

for df in [scaled_df, crypto_pca_df]:
    k_model = KMeans(n_clusters=4, random_state=0)
    k_model.fit(df)
    labels = k_model.labels_
    score = metrics.calinski_harabasz_score(df, labels)

    # show score
    print(score)
# Out:
# 32.45985294262567
# 51.45569397098449
